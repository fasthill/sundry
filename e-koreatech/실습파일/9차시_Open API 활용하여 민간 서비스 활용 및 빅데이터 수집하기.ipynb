# %%
# 네이버 Open API 로 파파고 활용하기 : 영어 -> 한글
import requests

# Naver API KEY 설정
client_id = "OXW8SVQW8yO4PqtzAyWn"
client_secret = "GmhEgmhZjw"

# 파파고 API 요청 URL
url = "https://openapi.naver.com/v1/papago/n2mt"

f = open('c:\\py_temp\\source.txt', encoding='utf-8') # 원본 파일
data = f.read() # 번역 대상 문자열
f_result = open("c:\\py_temp\\trans_result.txt", 'w') # 결과 저장 파일

# API Key 헤더 삽입
headers = {"X-Naver-Client-Id":'OXW8SVQW8yO4PqtzAyWn', "X-Naver-Client-Secret":"GmhEgmhZjw"}

# 영어 -> 한글로 번역 지정
params = {"source":"en", "target":"ko", "text":data}

try:
    response = requests.post(url, headers=headers, data=params)
    result = response.json()
    
    # 결과 json response에서 번역된 값만 추출하여 저장
    f_result.write(result['message']['result']['translatedText'])

    print('번역결과:',result['message']['result']['translatedText'])

except Exception as e:
    print(e)

f.close()
f_result.close()
# Out:
# 번역결과: 나는 파이썬 프로그램을 좋아한다.

# %%
# 네이버 Open API 로 파파고 활용하기 : 한글 -> 영어
import requests

# Naver API KEY 설정
client_id = "OXW8SVQW8yO4PqtzAyWn"
client_secret = "GmhEgmhZjw"

# 파파고 API 요청 URL
url = "https://openapi.naver.com/v1/papago/n2mt"

f = open('c:\\py_temp\\source_2.txt', encoding='utf-8') # 원본 파일
data = f.read() # 번역 대상 문자열
f_result = open("c:\\py_temp\\trans_result2.txt", 'w') # 결과 저장 파일

# API Key 헤더 삽입
headers = {"X-Naver-Client-Id":'OXW8SVQW8yO4PqtzAyWn', "X-Naver-Client-Secret":"GmhEgmhZjw"}

# 영어 -> 한글로 번역 지정
params = {"source":"ko", "target":"en", "text":data}

try:
    response = requests.post(url, headers=headers, data=params)
    result = response.json()
    
    # 결과 json response에서 번역된 값만 추출하여 저장
    f_result.write(result['message']['result']['translatedText'])

    print('번역결과:',result['message']['result']['translatedText'])

except Exception as e:
    print(e)

f.close()
f_result.close()
# Out:
# 번역결과: I like apples and bananas.
# I like mangoes and apples.
# I like apples, but I hate cherries.

# %%
# 네이버 검색 API 예제 - 블로그 검색
# https://developers.naver.com/docs/serviceapi/search/blog/blog.md#python

import os
import sys
import urllib.request
from bs4 import BeautifulSoup

client_id = "Vg0ERJSgcEf2SVsNBcuy"
client_secret = "G7zA0M33y4"

query_txt = urllib.parse.quote("서진수 빅데이터")
url = "https://openapi.naver.com/v1/search/blog?query=" + query_txt # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query_txt # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id","Vg0ERJSgcEf2SVsNBcuy")
request.add_header("X-Naver-Client-Secret","G7zA0M33y4")
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 02 Jan 2023 17:42:05 +0900",
# 	"total":211,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"전문가에게 길을 묻다. <b>빅데이터<\/b> 전문가편 <b>서진수<\/b> 대표",
# 			"link":"https:\/\/blog.naver.com\/n_jiyoung84\/222841311950",
# 			"description":"<b>빅데이터<\/b> 전문가편을 진행하였습니다. 각종 티비 프로그램과 인공지능과 관련된 18권의 책 출판, 국회에 4차 산업혁명 특별 자문위원, 세계인명사전에 과학자로 등재된 <b>서진수<\/b> 대표님과 함께 했습니다. 예전에... ",
# 			"bloggername":"뉴턴의과학실&뷰사이언스",
# 			"bloggerlink":"blog.naver.com\/n_jiyoung84",
# 			"postdate":"20220806"
# 		},
# 		{
# 			"title":"마소캠퍼스 <b>빅데이터<\/b> 분석 오픈 세미나!(<b>서진수<\/b> 대표님) 151030",
# 			"link":"https:\/\/blog.naver.com\/zzsza\/220524965474",
# 			"description":"오늘은 '마소캠퍼스'에서 진행한 <b>빅데이터<\/b> 분석 오픈 세미나 강연 후기입니다 진행은 <b>서진수<\/b> 대표님이... 하락중인 <b>데이터<\/b>를 보고 어떤 인사이트를 얻을 수 있는지, 차례 차례 알려주셨습니다 건설업계 \/ 교육... ",
# 			"bloggername":"어쩐지 오늘은",
# 			"bloggerlink":"blog.naver.com\/zzsza",
# 			"postdate":"20151031"
# 		},
# 		{
# ...

# %%
content = response_body.decode('utf-8')

# 불러온 데이터를 json 형태로 변경
import json
json_data = json.loads(content)
print(json_data)
print()
print('데이터타입:',type(json_data)) #json타입 확인
# Out:
# {'lastBuildDate': 'Mon, 02 Jan 2023 17:42:05 +0900', 'total': 211, 'start': 1, 'display': 10, 'items': [{'title': '전문가에게 길을 묻다. <b>빅데이터</b> 전문가편 <b>서진수</b> 대표', 'link': 'https://blog.naver.com/n_jiyoung84/222841311950', 'description': '<b>빅데이터</b> 전문가편을 진행하였습니다. 각종 티비 프로그램과 인공지능과 관련된 18권의 책 출판, 국회에 4차 산업혁명 특별 자문위원, 세계인명사전에 과학자로 등재된 <b>서진수</b> 대표님과 함께 했습니다. 예전에... ', 'bloggername': '뉴턴의과학실&뷰사이언스', 'bloggerlink': 'blog.naver.com/n_jiyoung84', 'postdate': '20220806'}, {'title': '마소캠퍼스 <b>빅데이터</b> 분석 오픈 세미나!(<b>서진수</b> 대표님) 151030', 'link': 'https://blog.naver.com/zzsza/220524965474', 'description': "오늘은 '마소캠퍼스'에서 진행한 <b>빅데이터</b> 분석 오픈 세미나 강연 후기입니다 진행은 <b>서진수</b> 대표님이... 하락중인 <b>데이터</b>를 보고 어떤 인사이트를 얻을 수 있는지, 차례 차례 알려주셨습니다 건설업계 / 교육... ", 'bloggername': '어쩐지 오늘은', 'bloggerlink': 'blog.naver.com/zzsza', 'postdate': '20151031'}, {'title': '<b>빅데이터</b> 전문가 <b>서진수</b> 대표의 트랜드 분석 강의', 'link': 'https://blog.naver.com/cafe_blue/220952121400', 'description': '<b>빅데이터</b> 전문가 <b>서진수</b> 대표님. <b>빅
# ...

# %%
# 필요한 값만 추출하기
data = json_data['items']

# Dataframe으로 만들기
import pandas as pd
df = pd.json_normalize(data)
df
# Out:
#                                                title  \
# 0        전문가에게 길을 묻다. <b>빅데이터</b> 전문가편 <b>서진수</b> 대표
# 1  마소캠퍼스 <b>빅데이터</b> 분석 오픈 세미나!(<b>서진수</b> 대표님) 1...
# 2           <b>빅데이터</b> 전문가 <b>서진수</b> 대표의 트랜드 분석 강의
# 3                             <b>서진수</b> 대표님의 강의를 듣고
# 4   소셜포럼] <b>서진수</b> 대표, 변화의 흐름을 이끄는 <b>빅데이터</b>...
# 5  방법, <b>빅데이터</b> 관리가 가장 기본 &lt;(주)컨시어지소프트 <b>서진...
# 6  <b>빅데이터</b> 활용으로 4차산업시대를 준비하자_<b>서진수</b>대표 특강...
# 7  <b>빅데이터</b> 전문가 <b>서진수</b> 강사님의 <b>빅데이터</b> 활용...
# 8   <b>빅데이터</b> 분석, 웹크롤링 강남 아이티윌과 <b>서진수</b> 강사님의 특강
# 9  [모임소개] KBS &quot;명견만리&quot; <b>서진수</b> 직강 &apo...
#
#                                                link  \
# 0   https://blog.naver.com/n_jiyoung84/222841311950
# 1         https://blog.naver.com/zzsza/220524965474
# 2     https://blog.naver.com/cafe_blue/220952121400
# 3       https://blog.naver.com/leeloro/222286053898
# 4  https://blog.naver.com/social_forum/221081115632
# 5       https://blog.naver.com/osh0416/221104952067
# ...
