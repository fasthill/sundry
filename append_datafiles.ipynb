# %%
import pickle
import pandas as pd

# %%
kosdaq_nas = pd.read_pickle('kosdaq_nas_'+str(0)+'.pkl')

# %%
for i in range(50,1270,50):
    kosdaq_nas = kosdaq_nas.append(pd.read_pickle('kosdaq_nas_'+str(i)+'.pkl'))

# %%
kosdaq_nas.shape
# Out:
# (3929, 9)

# %%
kosdaq_nyse = pd.read_pickle('kosdaq_nyse_'+str(0)+'.pkl')

# %%
for i in range(50,1270,50):
    kosdaq_nyse = kosdaq_nyse.append(pd.read_pickle('kosdaq_nyse_'+str(i)+'.pkl'))

# %%
kosdaq_nyse[kosdaq_nyse['sum'] >= 100]
# Out:
#       kospi nasdaq  ge(0)  le(0)  eq(0)  sum  ge(0)-ratio  le(0)-ratio  \
# 72   050120   CANO     99     53     20  132     0.750000     0.401515
# 222  178920    RZB     99     53     20  132     0.750000     0.401515
# 32   900070     LU     99     50     17  132     0.750000     0.378788
# 91   032190   ECOM     99     47     14  132     0.750000     0.356061
# 229  131220   SKLZ     99     49     16  132     0.750000     0.371212
# 179  030350    BGY    101     53     22  132     0.765152     0.401515
# 121  228850    GPX     99     48     15  132     0.750000     0.363636
# 203  277070    GIM    100     54     22  132     0.757576     0.409091
# 5    267980   DECK     99     46     13  132     0.750000     0.348485
# 6    267980    ARW     99     47     14  132     0.750000     0.356061
# 26   072870   HNGR     99     51     18  132     0.750000     0.386364
# 216  093190    LGI     99     46     13  132     0.750000     0.348485
# ...

# %%
kosdaq_nyse['sum'].ge(100).value_counts()[True]
# Out:
# 25

# %%
kospi_nyse = pd.read_pickle('kospi_nyse_'+str(0)+'.pkl')

# %%
for i in range(50,780,50):
    kospi_nyse = kospi_nyse.append(pd.read_pickle('kospi_nyse_'+str(i)+'.pkl'))

# %%
kospi_nas = pd.read_pickle('kospi_nas_'+str(0)+'.pkl')

# %%
for i in range(50,780,50):
    kospi_nas = kospi_nas.append(pd.read_pickle('kospi_nas_'+str(i)+'.pkl'))

# %%
kospi_nas.shape
# Out:
# (3031, 9)

# %%
kospi_nas[kospi_nas['sum'] >= 100]
# Out:
#      kospi nasdaq  ge(0)  le(0)  eq(0)  sum  ge(0)-ratio  le(0)-ratio  \
# 11  016610    CHK     79     36     10  105     0.752381     0.342857
# 64  007700   ECOL     99     51     19  131     0.755725     0.389313
# 65  007700   BSET     99     51     19  131     0.755725     0.389313
# 68  012630    CHK     80     38     13  105     0.761905     0.361905
# 79  105560   UBSI     99     37      5  131     0.755725     0.282443
# 0   025000   SPWH     99     50     18  131     0.755725     0.381679
# 3   000040   RMCF     54     99     22  131     0.412214     0.755725
# 17  017670   PDEX    100     40      9  131     0.763359     0.305344
# 25  005610  TMKRU     95     52     21  126     0.753968     0.412698
# 44  035250   VINO     85     36      9  112     0.758929     0.321429
# 62  010130  SGAMU     75     39     14  100     0.750000     0.390000
# 10  024110   STLD     99     46     14  131     0.755725     0.351145
# ...
